# %% [markdown]
# <a href="https://colab.research.google.com/github/sergio1/estudos/blob/main/codigo1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
temperatura = 23

print("Temperatura atual:", temperatura, "°C")
# Out:
# Temperatura atual: 23 °C
