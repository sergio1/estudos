# %% [markdown]
# <a href="https://colab.research.google.com/github/sergio1/estudos/blob/main/exercicio1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import sys
def sugerir_viagem(clima, tipo_de_ambiente, categoria):
  # Lista com 20 registros de ambientes
  destinos = {
  ("quente", "natureza", "econômico"): [
      {"local": "Chapada Diamantina (BA)", "descricao": "Trilhas, cachoeiras e montanhas com hospedagens acessíveis."}
  ],
  ("quente", "natureza", "intermediário"): [
      {"local": "Chapada dos Veadeiros (GO)", "descricao": "Cachoeiras e paisagens únicas em meio ao Cerrado."}
  ],
  ("quente", "natureza", "luxo"): [
      {"local": "Bonito (MS)", "descricao": "Rios cristalinos e resorts ecológicos sofisticados."},
      {"local": "Lençóis Maranhenses (MA)", "descricao": "Hospedagens premium com vista para dunas e lagoas."}
  ],

  ("frio", "natureza", "econômico"): [
      {"local": "Urubici (SC)", "descricao": "Natureza exuberante e hospedagens simples nas montanhas."}
  ],
  ("frio", "natureza", "intermediário"): [
      {"local": "Gramado (RS)", "descricao": "Clima serrano e natureza charmosa com custo moderado."},
      {"local": "Monte Verde (MG)", "descricao": "Trilhas e chalés aconchegantes."}
  ],
  ("frio", "natureza", "luxo"): [
      {"local": "Campos do Jordão (SP)", "descricao": "Hotéis de luxo e gastronomia de montanha."}
  ],

  ("quente", "paisagens urbanas", "econômico"): [
      {"local": "Salvador (BA)", "descricao": "História, cultura e praias com hospedagens acessíveis."},
      {"local": "Recife (PE)", "descricao": "Vida urbana e cultura nordestina a preços moderados."}
  ],
  ("quente", "paisagens urbanas", "intermediário"): [
      {"local": "Rio de Janeiro (RJ)", "descricao": "Paisagens icônicas e conforto urbano."},
      {"local": "Fortaleza (CE)", "descricao": "Praias e animação urbana com bom custo-benefício."}
  ],
  ("quente", "paisagens urbanas", "luxo"): [
      {"local": "Natal (RN)", "descricao": "Resorts à beira-mar e experiências exclusivas."}
  ],

  ("frio", "paisagens urbanas", "econômico"): [
      {"local": "Curitiba (PR)", "descricao": "Cidade organizada com parques e hospedagens acessíveis."},
      {"local": "Petrópolis (RJ)", "descricao": "Arquitetura imperial e bom custo-benefício."}
  ],
  ("frio", "paisagens urbanas", "intermediário"): [
      {"local": "São Paulo (SP)", "descricao": "Vida urbana intensa e gastronomia diversificada."}
  ],
  ("frio", "paisagens urbanas", "luxo"): [
      {"local": "Bento Gonçalves (RS)", "descricao": "Vinícolas e hotéis de alto padrão na serra gaúcha."}
  ]
  }

  chave = (clima, tipo_de_ambiente, categoria)
  if chave in destinos:
    return destinos[chave]
  else:
    return 'Nenhum destino encontrado para essa combinação.'


def main():
  cod_clima=int(input("Você prefere clima [1]=Quente ou [2]=Frio? "))
  if cod_clima not in (1,2):
      print('Foi informado opção incorreta!!!')
      print('Informe [1]=Quente ou [2]=Frio')
      sys.exit(1)

  if cod_clima == 1:
    clima='quente'
  else:
    clima='frio'

  cod_tipo_de_ambiente=int(input("Prefere lugares com [1]=Natureza ou [2]=Paisagens Urbanas? "))
  if cod_tipo_de_ambiente not in (1,2):
      print('Foi informado opção incorreta!!!')
      print('Informe [1]=Natureza ou [2]=Paisagens Urbanas')
      sys.exit(1)

  if cod_tipo_de_ambiente == 1:
    tipo_de_ambiente='natureza'
  else:
    tipo_de_ambiente='paisagens urbanas'

  valor=float(input("Qual é o seu orçamento disponível para a viagem? "))
  # Define categoria de acordo com preço
  if valor <= 400.00:
      categoria = "econômico"
  elif valor >= 401.00 and valor <= 700.00:
      categoria = "intermediário"
  else:
      categoria = "luxo"

  print(f"\n Procurando destinos {categoria} com clima {clima} e ambiente {tipo_de_ambiente}...\n")
  sugestoes = sugerir_viagem(clima, tipo_de_ambiente, categoria)
  for s in sugestoes:
    print(f" {s['local']}\n {s['descricao']}\n")


if __name__ == "__main__":
    main()
# Out:
# Você prefere clima [1]=Quente ou [2]=Frio? 1
# Prefere lugares com [1]=Natureza ou [2]=Paisagens Urbanas? 1
# Qual é o seu orçamento disponível para a viagem? 520
#
# 🧭 Procurando destinos intermediário com clima quente e ambiente natureza...
#
# 🌍 Chapada dos Veadeiros (GO)
# 📝 Cachoeiras e paisagens únicas em meio ao Cerrado.
